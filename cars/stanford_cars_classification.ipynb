# %% [markdown]
# # Car classifier

# %% [markdown]
# Based on the fast.ai course Lesson1, try building a car classifier and test its accuracy

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %%
bs = 64
# bs = 16   # uncomment this line if you run out of memory even after clicking Kernel->Restart

# %% [markdown]
# ## Looking at the data

# %% [markdown]
# We are going to use the [Stanford Cars Dataset](https://ai.stanford.edu/~jkrause/cars/car_dataset.html) by [J. Krause et al., 2013](https://ai.stanford.edu/~jkrause/papers/3drr13.pdf) which features 196 classes of cars. Our model will need to learn to differentiate between these 196 distinct categories. According to their paper, the best accuracy they could get in 2013 was 94.5%.

# %% [markdown]
# Download the stanford cars image dataset to the destination folder using kaggle API

# %%
img_dir='/home/jupyter/.fastai/data/car_data/car_data'
path=Path(img_dir)
data = ImageDataBunch.from_folder(path, valid_pct = 0.2, ds_tfms=get_transforms(),size=224,bs=bs).normalize(imagenet_stats)

# %%
data.show_batch(rows=3, figsize=(15,15))

# %% [markdown]
# Check the labels for first few images

# %%
len(data.classes)
data.classes[0:10]
# Out:
# ['AM General Hummer SUV 2000',
#  'Acura Integra Type R 2001',
#  'Acura RL Sedan 2012',
#  'Acura TL Sedan 2012',
#  'Acura TL Type-S 2008',
#  'Acura TSX Sedan 2012',
#  'Acura ZDX Hatchback 2012',
#  'Aston Martin V8 Vantage Convertible 2012',
#  'Aston Martin V8 Vantage Coupe 2012',
#  'Aston Martin Virage Convertible 2012']

# %% [markdown]
# ## Training: resnet34

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (1): Sequential(
#     (0): AdaptiveConcatPool2d(
#       (ap): AdaptiveAvgPool2d(output_size=1)
#       (mp): AdaptiveMaxPool2d(output_size=1)
#     )
#     (1): Flatten()
#     (2): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=1024, out_features=512, bias=True)
#     (5): ReLU(inplace=True)
#     (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.5, inplace=False)
#     (8): Linear(in_features=512, out_features=196, bias=True)
#   )
# )

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.772399</td>
#       <td>3.297027</td>
#       <td>0.756874</td>
#       <td>01:41</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.201599</td>
#       <td>2.275173</td>
#       <td>0.582638</td>
#       <td>01:45</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.391313</td>
#       <td>1.793830</td>
#       <td>0.462465</td>
#       <td>01:44</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.015001</td>
#       <td>1.715718</td>
#       <td>0.432190</td>
#       <td>01:45</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %% [markdown]
# ## Results

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.most_confused(min_val=2)
# Out:
# [('Chevrolet Silverado 1500 Hybrid Crew Cab 2012',
#   'Chevrolet Silverado 1500 Extended Cab 2012',
#   7),
#  ('Audi V8 Sedan 1994', 'Audi 100 Sedan 1994', 6),
#  ('Bentley Continental GT Coupe 2007',
#   'Bentley Continental Flying Spur Sedan 2007',
#   6),
#  ('GMC Savana Van 2012', 'Chevrolet Express Cargo Van 2007', 6),
#  ('Audi TT Hatchback 2011', 'Audi TTS Coupe 2012', 5),
#  ('Dodge Caliber Wagon 2012', 'Dodge Caliber Wagon 2007', 5),
#  ('Mercedes-Benz Sprinter Van 2012', 'Dodge Sprinter Cargo Van 2009', 5),
#  ('Acura TSX Sedan 2012', 'Acura TL Sedan 2012', 4),
#  ('Audi A5 Coupe 2012', 'Audi S5 Coupe 2012', 4),
#  ('Audi RS 4 Convertible 2008', 'Audi S5 Convertible 2012', 4),
#  ('Audi TT RS Coupe 2012', 'Audi TT Hatchback 2011', 4),
#  ('Audi V8 Sedan 1994', 'Volvo 240 Sedan 1993', 4),
#  ('Bentley Mulsanne Sedan 2011', 'Bentley Arnage Sedan 2009', 4),
#  ('Bugatti Veyron 16.4 Convertible 2009', 'Bugatti Veyron 16.4 Coupe 2009', 4),
#  ('Bugatti Veyron 16.4 Coupe 2009', 'Bugatti Veyron 16.4 Convertible 2009', 4),
#  ('Chevrolet Silverado 2500HD Regular Cab 2012',
#   'Chevrolet Silverado 1500 Regular Cab 2012',
#   4),
#  ('Chevrolet Traverse SUV 2012', 'Hyundai Veracruz SUV 2012', 4),
#  ('Acura TL Type-S 2008', 'Acura TL Sedan 2012', 3),
#  ('Audi S4 Sedan 2012', 'Audi TTS Coupe 2012', 3),
#  ('Audi S5 Coupe 2012', 'Audi A5 Coupe 2012', 3),
#  ('Audi S5 Coupe 2012', 'Audi S5 Convertible 2012', 3),
#  ('Audi S6 Sedan 2011', 'Audi S4 Sedan 2007', 3),
#  ('Audi V8 Sedan 1994', 'Audi 100 Wagon 1994', 3),
#  ('BMW 6 Series Convertible 2007', 'BMW M6 Convertible 2010', 3),
#  ('Bentley Continental Flying Spur Sedan 2007',
#   'Bentley Continental GT Coupe 2007',
#   3),
#  ('Bentley Mulsanne Sedan 2011', 'Chrysler 300 SRT-8 2010', 3),
#  ('Chevrolet Express Cargo Van 2007', 'Chevrolet Express Van 2007', 3),
#  ('Chevrolet Monte Carlo Coupe 2007', 'Chevrolet Impala Sedan 2007', 3),
#  ('Chevrolet Silverado 1500 Classic Extended Cab 2007',
#   'Chevrolet Avalanche Crew Cab 2012',
#   3),
#  ('Chevrolet Silverado 1500 Extended Cab 2012',
#   'Chevrolet Silverado 1500 Regular Cab 2012',
#   3),
#  ('Dodge Durango SUV 2007', 'Dodge Ram Pickup 3500 Crew Cab 2010', 3),
#  ('Eagle Talon Hatchback 1998', 'Chevrolet Monte Carlo Coupe 2007', 3),
#  ('Ferrari 458 Italia Convertible 2012', 'Ferrari 458 Italia Coupe 2012', 3),
#  ('HUMMER H3T Crew Cab 2010', 'HUMMER H2 SUT Crew Cab 2009', 3),
#  ('Honda Accord Coupe 2012', 'Chevrolet Cobalt SS 2010', 3),
#  ('Nissan 240SX Coupe 1998', 'Plymouth Neon Coupe 1999', 3),
#  ('Rolls-Royce Phantom Drophead Coupe Convertible 2012',
#   'Rolls-Royce Phantom Sedan 2012',
#   3),
#  ('Acura RL Sedan 2012', 'Acura TL Sedan 2012', 2),
#  ('Acura RL Sedan 2012', 'Toyota Camry Sedan 2012', 2),
#  ('Acura ZDX Hatchback 2012', 'Hyundai Tucson SUV 2012', 2),
#  ('Aston Martin V8 Vantage Convertible 2012',
#   'Aston Martin V8 Vantage Coupe 2012',
#   2),
#  ('Aston Martin V8 Vantage Convertible 2012',
#   'BMW 6 Series Convertible 2007',
#   2),
#  ('Aston Martin V8 Vantage Coupe 2012', 'Fisker Karma Sedan 2012', 2),
#  ('Audi 100 Sedan 1994', 'Audi 100 Wagon 1994', 2),
#  ('Audi 100 Sedan 1994', 'Audi V8 Sedan 1994', 2),
#  ('Audi 100 Sedan 1994', 'Volvo 240 Sedan 1993', 2),
#  ('Audi R8 Coupe 2012', 'Audi TT RS Coupe 2012', 2),
#  ('Audi S4 Sedan 2007', 'Audi S6 Sedan 2011', 2),
#  ('Audi S4 Sedan 2012', 'Audi S4 Sedan 2007', 2),
#  ('Audi S5 Coupe 2012', 'Mercedes-Benz C-Class Sedan 2012', 2),
#  ('Audi TT Hatchback 2011', 'Audi S4 Sedan 2007', 2),
#  ('Audi TTS Coupe 2012', 'Audi TT Hatchback 2011', 2),
#  ('Audi TTS Coupe 2012', 'Dodge Charger SRT-8 2009', 2),
#  ('BMW 3 Series Sedan 2012', 'BMW 3 Series Wagon 2012', 2),
#  ('BMW 6 Series Convertible 2007', 'BMW 1 Series Convertible 2012', 2),
#  ('BMW 6 Series Convertible 2007', 'Eagle Talon Hatchback 1998', 2),
#  ('BMW 6 Series Convertible 2007', 'Ford Mustang Convertible 2007', 2),
#  ('BMW M3 Coupe 2012', 'Volkswagen Golf Hatchback 2012', 2),
#  ('BMW M5 Sedan 2010', 'Acura TL Type-S 2008', 2),
#  ('BMW X3 SUV 2012', 'BMW 3 Series Wagon 2012', 2),
#  ('BMW X3 SUV 2012', 'BMW X6 SUV 2012', 2),
#  ('Bentley Continental Flying Spur Sedan 2007',
#   'Bentley Continental Supersports Conv. Convertible 2012',
#   2),
#  ('Bentley Continental Flying Spur Sedan 2007',
#   'Chevrolet Malibu Hybrid Sedan 2010',
#   2),
#  ('Bentley Continental GT Coupe 2007', 'Bentley Continental GT Coupe 2012', 2),
#  ('Bentley Continental GT Coupe 2012', 'Bentley Continental GT Coupe 2007', 2),
#  ('Buick Rainier SUV 2007', 'Buick Enclave SUV 2012', 2),
#  ('Chevrolet Avalanche Crew Cab 2012',
#   'Chevrolet Silverado 1500 Extended Cab 2012',
#   2),
#  ('Chevrolet Corvette Convertible 2012', 'Chevrolet Corvette ZR1 2012', 2),
#  ('Chevrolet Corvette Convertible 2012', 'Lamborghini Diablo Coupe 2001', 2),
#  ('Chevrolet Corvette Ron Fellows Edition Z06 2007',
#   'Chevrolet Corvette ZR1 2012',
#   2),
#  ('Chevrolet Express Van 2007', 'Chevrolet Express Cargo Van 2007', 2),
#  ('Chevrolet Express Van 2007', 'GMC Savana Van 2012', 2),
#  ('Chevrolet HHR SS 2010', 'Scion xD Hatchback 2012', 2),
#  ('Chevrolet Impala Sedan 2007', 'Chevrolet Malibu Sedan 2007', 2),
#  ('Chevrolet Malibu Sedan 2007', 'Chevrolet Impala Sedan 2007', 2),
#  ('Chevrolet Monte Carlo Coupe 2007', 'Lincoln Town Car Sedan 2011', 2),
#  ('Chevrolet Silverado 1500 Classic Extended Cab 2007',
#   'Chevrolet Silverado 1500 Extended Cab 2012',
#   2),
#  ('Chevrolet Silverado 1500 Extended Cab 2012',
#   'Chevrolet Silverado 1500 Hybrid Crew Cab 2012',
#   2),
#  ('Chevrolet Silverado 1500 Hybrid Crew Cab 2012',
#   'Chevrolet Avalanche Crew Cab 2012',
#   2),
#  ('Chevrolet Silverado 1500 Hybrid Crew Cab 2012',
#   'Chevrolet Silverado 1500 Regular Cab 2012',
#   2),
#  ('Chevrolet Silverado 1500 Hybrid Crew Cab 2012',
#   'GMC Canyon Extended Cab 2012',
#   2),
#  ('Chevrolet Silverado 1500 Regular Cab 2012',
#   'Chevrolet Silverado 1500 Extended Cab 2012',
#   2),
#  ('Chevrolet Silverado 1500 Regular Cab 2012',
#   'Chevrolet Silverado 1500 Hybrid Crew Cab 2012',
#   2),
#  ('Chevrolet Silverado 2500HD Regular Cab 2012',
#   'Ford Ranger SuperCab 2011',
#   2),
#  ('Chevrolet Tahoe Hybrid SUV 2012', 'Toyota Sequoia SUV 2012', 2),
#  ('Chevrolet TrailBlazer SS 2009', 'Jeep Grand Cherokee SUV 2012', 2),
#  ('Chevrolet Traverse SUV 2012', 'Hyundai Tucson SUV 2012', 2),
#  ('Chrysler Sebring Convertible 2010', 'BMW 1 Series Convertible 2012', 2),
#  ('Dodge Caliber Wagon 2007', 'Dodge Caliber Wagon 2012', 2),
#  ('Dodge Charger SRT-8 2009', 'Dodge Charger Sedan 2012', 2),
#  ('Dodge Charger Sedan 2012', 'Dodge Charger SRT-8 2009', 2),
#  ('Dodge Dakota Club Cab 2007', 'Ford Ranger SuperCab 2011', 2),
#  ('Dodge Dakota Crew Cab 2010', 'Dodge Dakota Club Cab 2007', 2),
#  ('Dodge Dakota Crew Cab 2010', 'Dodge Ram Pickup 3500 Quad Cab 2009', 2),
#  ('Dodge Dakota Crew Cab 2010', 'Ford Ranger SuperCab 2011', 2),
#  ('Dodge Journey SUV 2012', 'Cadillac SRX SUV 2012', 2),
#  ('Dodge Journey SUV 2012', 'Dodge Durango SUV 2012', 2),
#  ('Dodge Magnum Wagon 2008', 'Dodge Caliber Wagon 2007', 2),
#  ('Dodge Sprinter Cargo Van 2009', 'Mercedes-Benz Sprinter Van 2012', 2),
#  ('Ferrari California Convertible 2012', 'BMW Z4 Convertible 2012', 2),
#  ('Ferrari California Convertible 2012',
#   'Ferrari 458 Italia Convertible 2012',
#   2),
#  ('Ferrari California Convertible 2012', 'Ferrari FF Coupe 2012', 2),
#  ('Ferrari FF Coupe 2012', 'Aston Martin V8 Vantage Coupe 2012', 2),
#  ('Ferrari FF Coupe 2012', 'Volvo C30 Hatchback 2012', 2),
#  ('Fisker Karma Sedan 2012', 'Porsche Panamera Sedan 2012', 2),
#  ('Ford Edge SUV 2012', 'Honda Odyssey Minivan 2012', 2),
#  ('Ford F-150 Regular Cab 2007', 'Ford F-150 Regular Cab 2012', 2),
#  ('Ford F-150 Regular Cab 2012', 'Ford Ranger SuperCab 2011', 2),
#  ('Ford Focus Sedan 2007', 'Chevrolet Malibu Sedan 2007', 2),
#  ('Ford Focus Sedan 2007', 'Nissan 240SX Coupe 1998', 2),
#  ('Ford Freestar Minivan 2007', 'Chevrolet Traverse SUV 2012', 2),
#  ('Ford Mustang Convertible 2007', 'Chrysler Crossfire Convertible 2008', 2),
#  ('GMC Acadia SUV 2012', 'Chevrolet TrailBlazer SS 2009', 2),
#  ('GMC Acadia SUV 2012', 'Chevrolet Traverse SUV 2012', 2),
#  ('GMC Savana Van 2012', 'Chevrolet Express Van 2007', 2),
#  ('GMC Yukon Hybrid SUV 2012', 'Jeep Grand Cherokee SUV 2012', 2),
#  ('HUMMER H2 SUT Crew Cab 2009', 'Jeep Wrangler SUV 2012', 2),
#  ('Honda Accord Coupe 2012', 'Chevrolet Traverse SUV 2012', 2),
#  ('Honda Odyssey Minivan 2012', 'Buick Enclave SUV 2012', 2),
#  ('Honda Odyssey Minivan 2012', 'Honda Odyssey Minivan 2007', 2),
#  ('Hyundai Azera Sedan 2012', 'Hyundai Sonata Sedan 2012', 2),
#  ('Hyundai Veloster Hatchback 2012', 'Aston Martin Virage Coupe 2012', 2),
#  ('Jeep Patriot SUV 2012', 'Jeep Liberty SUV 2012', 2),
#  ('Jeep Patriot SUV 2012', 'Toyota 4Runner SUV 2012', 2),
#  ('Land Rover LR2 SUV 2012', 'Land Rover Range Rover SUV 2012', 2),
#  ('Land Rover Range Rover SUV 2012', 'Land Rover LR2 SUV 2012', 2),
#  ('Mercedes-Benz 300-Class Convertible 1993', 'Volvo 240 Sedan 1993', 2),
#  ('Mercedes-Benz E-Class Sedan 2012', 'Audi S5 Coupe 2012', 2),
#  ('Mercedes-Benz E-Class Sedan 2012', 'Mercedes-Benz S-Class Sedan 2012', 2),
#  ('Mercedes-Benz S-Class Sedan 2012', 'Suzuki SX4 Sedan 2012', 2),
#  ('Mitsubishi Lancer Sedan 2012', 'Toyota Corolla Sedan 2012', 2),
#  ('Nissan 240SX Coupe 1998', 'Chrysler Crossfire Convertible 2008', 2),
#  ('Nissan 240SX Coupe 1998', 'Dodge Charger SRT-8 2009', 2),
#  ('Nissan 240SX Coupe 1998', 'Eagle Talon Hatchback 1998', 2),
#  ('Nissan Juke Hatchback 2012', 'BMW X6 SUV 2012', 2),
#  ('Nissan Juke Hatchback 2012', 'Spyker C8 Convertible 2009', 2),
#  ('Porsche Panamera Sedan 2012', 'Volkswagen Beetle Hatchback 2012', 2),
#  ('Rolls-Royce Ghost Sedan 2012',
#   'Bentley Continental Flying Spur Sedan 2007',
#   2),
#  ('Rolls-Royce Ghost Sedan 2012', 'Rolls-Royce Phantom Sedan 2012', 2),
#  ('Rolls-Royce Phantom Drophead Coupe Convertible 2012',
#   'Rolls-Royce Ghost Sedan 2012',
#   2),
#  ('Spyker C8 Coupe 2009', 'Ford GT Coupe 2006', 2),
#  ('Suzuki Kizashi Sedan 2012', 'Mitsubishi Lancer Sedan 2012', 2),
#  ('Suzuki SX4 Hatchback 2012', 'Suzuki SX4 Sedan 2012', 2),
#  ('Toyota Camry Sedan 2012', 'Hyundai Sonata Hybrid Sedan 2012', 2),
#  ('Toyota Corolla Sedan 2012', 'Dodge Caliber Wagon 2007', 2),
#  ('Volkswagen Beetle Hatchback 2012', 'Suzuki SX4 Sedan 2012', 2),
#  ('Volkswagen Golf Hatchback 2012', 'BMW X5 SUV 2007', 2),
#  ('Volkswagen Golf Hatchback 2012', 'Mercedes-Benz C-Class Sedan 2012', 2)]

# %% [markdown]
# ## Unfreezing, fine-tuning, and learning rates

# %% [markdown]
# Since our model is working as we expect it to, we will *unfreeze* our model and train some more.

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.880213</td>
#       <td>1.161479</td>
#       <td>0.307074</td>
#       <td>01:42</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.load('stage-1');

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()
